# %% [markdown]
# # Introdução de Python para Geoprocessamento

# %% [markdown]
# ### 1. Importando bibliotecas

# %%
#Instalando a biblioteca pandas
# !pip install geopandas
# !pip install matplotlib
# !pip intall shapely

# !pip install descartes
# Out:
# Requirement already satisfied: geopandas in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (0.13.2)
# Requirement already satisfied: fiona>=1.8.19 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.0.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from geopandas) (2.0.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from fiona>=1.8.19->geopandas) (8.1.5)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from pandas>=1.1.0->geopandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from pandas>=1.1.0->geopandas) (1.25.1)
# Requirement already satisfied: colorama in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from click~=8.0->fiona>=1.8.19->geopandas) (0.4.6)
# Requirement already satisfied: matplotlib in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# ERROR: unknown command "intall" - maybe you meant "install"
# Requirement already satisfied: descartes in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (1.1.0)
# Requirement already satisfied: matplotlib in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from descartes) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib->descartes) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib->descartes) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib->descartes) (4.41.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib->descartes) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib->descartes) (1.25.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib->descartes) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib->descartes) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib->descartes) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from matplotlib->descartes) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\rodrigo cruz\anaconda3\envs\geopython\lib\site-packages (from python-dateutil>=2.7->matplotlib->descartes) (1.16.0)

# %%
#Versão das bibliotecas
# !conda list geopandas
# !conda list matplotlib
# Out:
# # packages in environment at C:\Users\Rodrigo Cruz\anaconda3\envs\geopython:
# #
# # Name                    Version                   Build  Channel
# geopandas                 0.13.2                   pypi_0    pypi
# # packages in environment at C:\Users\Rodrigo Cruz\anaconda3\envs\geopython:
# #
# # Name                    Version                   Build  Channel
# matplotlib                3.7.2                    pypi_0    pypi
# matplotlib-inline         0.1.6              pyhd8ed1ab_0    conda-forge

# %%
#Importação das bibliotecas
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point,LineString, Polygon

# %% [markdown]
# ### 2. Baixando dados geoespaciais
#
# Link: https://www.ibge.gov.br/geociencias/organizacao-do-territorio/malhas-territoriais/15774-malhas.html

# %% [markdown]
# ### 3. Lendo arquivos

# %%
# ler dados geopandas

data = gpd.read_file('data/PA_Municipios_2022/PA_Municipios_2022.shp')

# %%
# tipo de dados

type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
# dados da tabela de atributos
data.head()
# Out:
#     CD_MUN              NM_MUN SIGLA_UF  AREA_KM2  \
# 0  1500107          Abaetetuba       PA  1610.654
# 1  1500131     Abel Figueiredo       PA   614.131
# 2  1500206               Acará       PA  4344.384
# 3  1500305                Afuá       PA  8338.438
# 4  1500347  Água Azul do Norte       PA  7113.955
#
#                                             geometry
# 0  POLYGON ((-48.91969 -1.94722, -48.91996 -1.946...
# 1  POLYGON ((-48.39828 -4.86941, -48.39526 -4.870...
# 2  POLYGON ((-48.36255 -1.47566, -48.36046 -1.473...
# 3  POLYGON ((-50.58316 -0.66965, -50.58467 -0.669...
# 4  POLYGON ((-50.53100 -7.14231, -50.53114 -7.142...

# %% [markdown]
# ### 4. Visualização dos dados geoespaciais

# %%
#plotando o mapa
data.plot()
# Out:
# <Axes: >

# %%
# editando a visualização
data.plot(figsize=(16,14), facecolor='w', edgecolor='black')
plt.show()

# %%
# filtrar somente a capital de Belém
cap_bel = data[data.NM_MUN == 'Belém']

# %%
# visualizar apenas a capital filtrada
cap_bel.plot(figsize=(8,8), facecolor = 'w', edgecolor='black')
plt.show()

# %% [markdown]
# #### Salvando os dados

# %%
# para salvar os dados geoespaciais
# geojson
filename = "data/_Saved/capital_belem.json"
cap_bel.to_file(filename, driver='GeoJSON')

# %%
#Abrindo arquivos

bel = gpd.read_file(filename, driver='GeoJSON')

bel.plot()
# Out:
# <Axes: >

# %% [markdown]
# ### 6. Criando geometrias

# %% [markdown]
# #### 6.1. Point (Ponto)

# %%
#Criando geometria do tipo ponto
ponto = Point(5,10)
ponto
# Out:
# <POINT (5 10)>

# %%
# Tipo da variavel
print(ponto, type(ponto))
# Out:
# POINT (5 10) <class 'shapely.geometry.point.Point'>

# %%
#Funçao coords
list(ponto.coords)
# Out:
# [(5.0, 10.0)]

# %%
# lendo x e y separadamente
x = ponto.x
y = ponto.y

print(x,y)
# Out:
# 5.0 10.0

# %%
# Como calcular a distancia entre dois pontos
point1 = Point(2,4)
point2 = Point(7,9)

distancia = point1.distance(point2)

print(f'A distancia entre dois pontos é: {distancia}')
# Out:
# A distancia entre dois pontos é: 7.0710678118654755

# %% [markdown]
# #### 6.2. LineString (Linha)

# %%
#Criando geometria do tipo linha

ponto1 = Point(2,3)
ponto2 = Point(5,7)
ponto3 = Point(2,10)

linha = LineString([ponto1,ponto2,ponto3])

linha
# Out:
# <LINESTRING (2 3, 5 7, 2 10)>

# %%
# Tipo da variavel
print(linha, type(linha))
# Out:
# LINESTRING (2 3, 5 7, 2 10) <class 'shapely.geometry.linestring.LineString'>

# %%
# Atributos e funções da linestring

#Funçao coords (Extrair as coordenadas)
list(linha.coords)

# lendo x e y separadamente
x = list(linha.xy[0])
y = list(linha.xy[1])

print(f'Coordenadas X: {x}, Coordenadas Y: {y}')
# Out:
# Coordenadas X: [2.0, 5.0, 2.0], Coordenadas Y: [3.0, 7.0, 10.0]

# %%
#Calcular o comprimento da linha
linha.length
# Out:
# 9.242640687119284

# %%
# Obter o ponto central (centroide)
print(linha.centroid)
# Out:
# POINT (3.5000000000000004 6.606601717798214)

# %% [markdown]
# #### 6.3. Polygon (Poligono)

# %%
#Criando geometria do tipo poligono
polygon = Polygon([(2,1),(5,7),(8,10),(12,6),(16,-9)])
polygon
# Out:
# <POLYGON ((2 1, 5 7, 8 10, 12 6, 16 -9, 2 1))>

# %%
# Tipo da variavel
print(polygon, type(polygon))
# Out:
# POLYGON ((2 1, 5 7, 8 10, 12 6, 16 -9, 2 1)) <class 'shapely.geometry.polygon.Polygon'>

# %%
#obter as coordenadas
polygon.exterior.coords

# %%
# calcular area
area = polygon.area

print(f"A area do poligon é: {area}")
# Out:
# A area do poligon é: 119.5

# %%
# obter o centroide do poligon
polygon_centroid = polygon.centroid

print(f'Centroide: {polygon_centroid}')
# Out:
# Centroide: POINT (9.142259414225942 1.1743375174337518)

# %%
# obter as coordenadas da bounding box
polygon.bounds
# Out:
# (2.0, -9.0, 16.0, 10.0)

# %%
# pegar as coordenadas da linha exterior
polygon_exter = polygon.exterior
print(polygon_exter)
# Out:
# LINEARRING (2 1, 5 7, 8 10, 12 6, 16 -9, 2 1)

# %%
# obter o tamanho da linha exterior (PERIMETRO)
polygon_perimetro = polygon.exterior.length

print(f'O perimetro do poligono: {polygon_perimetro}')
# Out:
# O perimetro do poligono: 49.33652409945631

# %% [markdown]
# ### 7. Operações básicas entre geometrias ( Ferramentas de Geoprocessamento)

# %% [markdown]
# #### 7.1. BUFFER

# %%
# Criar circulos (BUFFER)
buffer1 = Point(1,1).buffer(1)
buffer1
# Out:
# <POLYGON ((2 1, 1.995 0.902, 1.981 0.805, 1.957 0.71, 1.924 0.617, 1.882 0.5...>

# %% [markdown]
# #### 7.2 INTERSEÇÃO

# %%
# Criar dois poligonos para usar como exemplo
circulo1 = Point(1,1).buffer(1)
circulo2 = Point(2,1).buffer(1)

## Plotar os poligonos
x,y= circulo1.exterior.xy
plt.plot(x,y)

x,y = circulo2.exterior.xy
plt.plot(x,y)

plt.show()

# %%
# Fazendo a Interseção
circulo_inter = circulo1.intersection(circulo2)
circulo_inter
# Out:
# <POLYGON ((1.995 0.902, 1.981 0.805, 1.957 0.71, 1.924 0.617, 1.882 0.529, 1...>

# %% [markdown]
# #### 7.3. UNIÃO

# %%
circulo_union = circulo1.union(circulo2)

circulo_union
# Out:
# <POLYGON ((1.471 0.118, 1.383 0.076, 1.29 0.043, 1.195 0.019, 1.098 0.005, 1...>

# %% [markdown]
# #### 7.4. DIFERENÇA

# %%
circulo_dif1 = circulo1.difference(circulo2)
circulo_dif1
# Out:
# <POLYGON ((1.471 0.118, 1.383 0.076, 1.29 0.043, 1.195 0.019, 1.098 0.005, 1...>

# %%
circulo_dif2 = circulo2.difference(circulo1)
circulo_dif2
# Out:
# <POLYGON ((2.995 0.902, 2.981 0.805, 2.957 0.71, 2.924 0.617, 2.882 0.529, 2...>

# %% [markdown]
# #### 7.5. DIFERENÇA SIMETRICA

# %%
circulo_dif_1 = circulo1.symmetric_difference(circulo2)
circulo_dif_1
# Out:
# <MULTIPOLYGON (((1.556 0.169, 1.634 0.227, 1.707 0.293, 1.773 0.366, 1.831 0...>
